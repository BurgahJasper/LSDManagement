# %%
#install packages
# !pip3 install requests
# !pip3 install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)

# %%
#import packages
import urllib.request
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Reinitialize every time yyou run the program create lists to store data scraped from web
authors = []
dates = []
statements = []
description = []

# %%
def scrape_data(page_number):
    page_num = str(page_number)
    print('scraping page number', page_num)
    URL= 'https://www.snopes.com/fact-check/?pagenum='+page_num
    webpage = requests.get(URL)
    soup = BeautifulSoup(webpage.text,"html.parser")

    article_quote = soup.find_all('h3', attrs={'class':'article_title'}) #Get the tag and it's class
    article_author =  soup.find_all('div',attrs={'class':'author_name_box'})  #Get the tag and it's class
    article_date = soup.find_all('span', attrs={'class':'article_date'})#Get the tag and it's class
    article_description = soup.find_all('span', attrs={'class':'article_byline'})#Get the tag and it's class
   
    #loop through heading
    for i in article_quote:
        text = i.text.strip()
        statements.append(text)
    print('statement length',len(statements))
    #Loop through author
    for i in article_author:
        text = i.find_all('span')[0]
        authors.append(text)
    print('authors length',len(authors))
    #Loop through dates
    for i in article_date:
        text = i.text.strip()
        dates.append(text)
    print('dates length',len(dates))        
    #Loop through description
    for i in article_description:
        text = i.text.strip()
        description.append(text)
    print('description length',len(description))

# %%
#Loop over 1 to 983 pages
for i in range(1, 983):
  scrape_data(i)
# Out:
# scraping page number 1
# statement length 20
# authors length 20
# dates length 20
# description length 20
# scraping page number 2
# statement length 40
# authors length 40
# dates length 40
# description length 40
# scraping page number 3
# statement length 60
# authors length 60
# dates length 60
# description length 60
# scraping page number 4
# statement length 80
# authors length 80
# dates length 80
# description length 80
# scraping page number 5
# statement length 100
# authors length 100
# dates length 100
# description length 100
# scraping page number 6
# statement length 120
# authors length 120
# dates length 120
# description length 120
# scraping page number 7
# statement length 140
# authors length 140
# dates length 140
# description length 140
# scraping page number 8
# statement length 160
# authors length 160
# dates length 160
# description length 160
# scraping page number 9
# statement length 180
# authors length 180
# dates length 180
# description length 180
# scraping page number 10
# statement length 200
# authors length 200
# dates length 200
# description length 200
# scraping page number 11
# statement length 220
# authors length 220
# dates length 220
# description length 220
# scraping page number 12
# statement length 240
# authors length 240
# dates length 240
# description length 240
# scraping page number 13
# statement length 260
# authors length 260
# dates length 260
# description length 260
# scraping page number 14
# statement length 280
# authors length 280
# dates length 280
# description length 280
# scraping page number 15
# statement length 300
# authors length 300
# dates length 300
# description length 300
# scraping page number 16
# statement length 320
# authors length 320
# dates length 320
# description length 320
# scraping page number 17
# statement length 340
# authors length 340
# dates length 340
# description length 340
# scraping page number 18
# statement length 360
# authors length 360
# dates length 360
# description length 360
# scraping page number 19
# statement length 380
# authors length 380
# dates length 380
# description length 380
# scraping page number 20
# statement length 400
# authors length 400
# dates length 400
# description length 400
# scraping page number 21
# statement length 420
# authors length 420
# dates length 420
# description length 420
# scraping page number 22
# statement length 440
# authors length 440
# dates length 440
# description length 440
# scraping page number 23
# statement length 460
# authors length 460
# dates length 460
# description length 460
# scraping page number 24
# statement length 480
# authors length 480
# dates length 480
# description length 480
# scraping page number 25
# statement length 500
# authors length 500
# dates length 500
# description length 500
# scraping page number 26
# statement length 520
# authors length 520
# dates length 520
# description length 520
# scraping page number 27
# statement length 540
# authors length 540
# dates length 540
# description length 540
# scraping page number 28
# statement length 560
# authors length 560
# dates length 560
# description length 560
# scraping page number 29
# statement length 580
# authors length 580
# dates length 580
# description length 580
# scraping page number 30
# statement length 600
# authors length 600
# dates length 600
# description length 600
# scraping page number 31
# statement length 620
# authors length 620
# dates length 620
# description length 620
# scraping page number 32
# statement length 640
# authors length 640
# dates length 640
# description length 640
# scraping page number 33
# statement length 660
# authors length 660
# dates length 660
# description length 660
# scraping page number 34
# statement length 680
# authors length 680
# dates length 680
# description length 680
# scraping page number 35
# statement length 700
# authors length 700
# dates length 700
# description length 700
# scraping page number 36
# statement length 720
# authors length 720
# dates length 720
# description length 720
# scraping page number 37
# statement length 740
# authors length 740
# dates length 740
# description length 740
# scraping page number 38
# statement length 760
# authors length 760
# dates length 760
# description length 760
# scraping page number 39
# statement length 780
# authors length 780
# dates length 780
# description length 780
# scraping page number 40
# statement length 800
# authors length 800
# dates length 800
# description length 800
# scraping page number 41
# statement length 820
# authors length 820
# dates length 820
# description length 820
# scraping page number 42
# statement length 840
# authors length 840
# dates length 840
# description length 840
# scraping page number 43
# statement length 860
# authors length 860
# dates length 860
# description length 860
# scraping page number 44
# statement length 880
# authors length 880
# dates length 880
# description length 880
# scraping page number 45
# statement length 900
# authors length 900
# dates length 900
# description length 900
# scraping page number 46
# statement length 920
# authors length 920
# dates length 920
# description length 920
# scraping page number 47
# statement length 940
# authors length 940
# dates length 940
# description length 940
# scraping page number 48
# statement length 960
# authors length 960
# dates length 960
# description length 960
# scraping page number 49
# statement length 980
# authors length 980
# dates length 980
# description length 980
# scraping page number 50
# statement length 1000
# authors length 1000
# dates length 1000
# description length 1000
# scraping page number 51
# statement length 1020
# authors length 1020
# dates length 1020
# description length 1020
# scraping page number 52
# statement length 1040
# authors length 1040
# dates length 1040
# description length 1040
# scraping page number 53
# statement length 1060
# authors length 1060
# dates length 1060
# description length 1060
# scraping page number 54
# statement length 1080
# authors length 1080
# dates length 1080
# description length 1080
# scraping page number 55
# statement length 1100
# authors length 1100
# dates length 1100
# description length 1100
# scraping page number 56
# statement length 1120
# authors length 1120
# dates length 1120
# description length 1120
# scraping page number 57
# statement length 1140
# authors length 1140
# dates length 1140
# description length 1140
# scraping page number 58
# statement length 1160
# authors length 1160
# dates length 1160
# description length 1160
# scraping page number 59
# statement length 1180
# authors length 1180
# dates length 1180
# description length 1180
# scraping page number 60
# statement length 1200
# authors length 1200
# dates length 1200
# description length 1200
# scraping page number 61
# statement length 1220
# authors length 1220
# dates length 1220
# description length 1220
# scraping page number 62
# statement length 1240
# authors length 1240
# dates length 1240
# description length 1240
# scraping page number 63
# statement length 1260
# authors length 1260
# dates length 1260
# description length 1260
# scraping page number 64
# statement length 1280
# authors length 1280
# dates length 1280
# description length 1280
# scraping page number 65
# statement length 1300
# authors length 1300
# dates length 1300
# description length 1300
# scraping page number 66
# statement length 1320
# authors length 1320
# dates length 1320
# description length 1320
# scraping page number 67
# statement length 1340
# authors length 1340
# dates length 1340
# description length 1340
# scraping page number 68
# statement length 1360
# authors length 1360
# dates length 1360
# description length 1360
# scraping page number 69
# statement length 1380
# authors length 1380
# dates length 1380
# description length 1380
# scraping page number 70
# statement length 1400
# authors length 1400
# dates length 1400
# description length 1400
# scraping page number 71
# statement length 1420
# authors length 1420
# dates length 1420
# description length 1420
# scraping page number 72
# statement length 1440
# authors length 1440
# dates length 1440
# description length 1440
# scraping page number 73
# statement length 1460
# authors length 1460
# dates length 1460
# description length 1460
# scraping page number 74
# statement length 1480
# authors length 1480
# dates length 1480
# description length 1480
# scraping page number 75
# statement length 1500
# authors length 1500
# dates length 1500
# description length 1500
# scraping page number 76
# statement length 1520
# authors length 1520
# dates length 1520
# description length 1520
# scraping page number 77
# statement length 1540
# authors length 1540
# dates length 1540
# description length 1540
# scraping page number 78
# statement length 1560
# authors length 1560
# dates length 1560
# description length 1560
# scraping page number 79
# statement length 1580
# authors length 1580
# dates length 1580
# description length 1580
# scraping page number 80
# statement length 1600
# authors length 1600
# dates length 1600
# description length 1600
# scraping page number 81
# statement length 1620
# authors length 1620
# dates length 1620
# description length 1620
# scraping page number 82
# statement length 1640
# authors length 1640
# dates length 1640
# description length 1640
# scraping page number 83
# statement length 1660
# authors length 1660
# dates length 1660
# description length 1660
# scraping page number 84
# statement length 1680
# authors length 1680
# dates length 1680
# description length 1680
# scraping page number 85
# statement length 1700
# authors length 1700
# dates length 1700
# description length 1700
# scraping page number 86
# statement length 1720
# authors length 1720
# dates length 1720
# description length 1720
# scraping page number 87
# statement length 1740
# authors length 1740
# dates length 1740
# description length 1740
# scraping page number 88
# statement length 1760
# authors length 1760
# dates length 1760
# description length 1760
# scraping page number 89
# statement length 1780
# authors length 1780
# dates length 1780
# description length 1780
# scraping page number 90
# statement length 1800
# authors length 1800
# dates length 1800
# description length 1800
# scraping page number 91
# statement length 1820
# authors length 1820
# dates length 1820
# description length 1820
# scraping page number 92
# statement length 1840
# authors length 1840
# dates length 1840
# description length 1840
# scraping page number 93
# statement length 1860
# authors length 1860
# dates length 1860
# description length 1860
# scraping page number 94
# statement length 1880
# authors length 1880
# dates length 1880
# description length 1880
# scraping page number 95
# statement length 1900
# authors length 1900
# dates length 1900
# description length 1900
# scraping page number 96
# statement length 1920
# authors length 1920
# dates length 1920
# description length 1920
# scraping page number 97
# statement length 1940
# authors length 1940
# dates length 1940
# description length 1940
# scraping page number 98
# statement length 1960
# authors length 1960
# dates length 1960
# description length 1960
# scraping page number 99
# statement length 1980
# authors length 1980
# dates length 1980
# description length 1980
# scraping page number 100
# statement length 2000
# authors length 2000
# dates length 2000
# description length 2000
# scraping page number 101
# statement length 2020
# authors length 2020
# dates length 2020
# description length 2020
# scraping page number 102
# statement length 2040
# authors length 2040
# dates length 2040
# description length 2040
# scraping page number 103
# statement length 2060
# authors length 2060
# dates length 2060
# description length 2060
# scraping page number 104
# statement length 2080
# authors length 2080
# dates length 2080
# description length 2080
# scraping page number 105
# statement length 2100
# authors length 2100
# dates length 2100
# description length 2100
# scraping page number 106
# statement length 2120
# authors length 2120
# dates length 2120
# description length 2120
# scraping page number 107
# statement length 2140
# authors length 2140
# dates length 2140
# description length 2140
# scraping page number 108
# statement length 2160
# authors length 2160
# dates length 2160
# description length 2160
# scraping page number 109
# statement length 2180
# authors length 2180
# dates length 2180
# description length 2180
# scraping page number 110
# statement length 2200
# authors length 2200
# dates length 2200
# description length 2200
# scraping page number 111
# statement length 2220
# authors length 2220
# dates length 2220
# description length 2220
# scraping page number 112
# statement length 2240
# authors length 2240
# dates length 2240
# description length 2240
# scraping page number 113
# statement length 2260
# authors length 2260
# dates length 2260
# description length 2260
# scraping page number 114
# statement length 2280
# authors length 2280
# dates length 2280
# description length 2280
# scraping page number 115
# statement length 2300
# authors length 2300
# dates length 2300
# description length 2300
# scraping page number 116
# statement length 2320
# authors length 2320
# dates length 2320
# description length 2320
# scraping page number 117
# statement length 2340
# authors length 2340
# dates length 2340
# description length 2340
# scraping page number 118
# statement length 2360
# authors length 2360
# dates length 2360
# description length 2360
# scraping page number 119
# statement length 2380
# authors length 2380
# dates length 2380
# description length 2380
# scraping page number 120
# statement length 2400
# authors length 2400
# dates length 2400
# description length 2400
# scraping page number 121
# statement length 2420
# authors length 2420
# dates length 2420
# description length 2420
# scraping page number 122
# statement length 2440
# authors length 2440
# dates length 2440
# description length 2440
# scraping page number 123
# statement length 2460
# authors length 2460
# dates length 2460
# description length 2460
# scraping page number 124
# statement length 2480
# authors length 2480
# dates length 2480
# description length 2480
# scraping page number 125
# statement length 2500
# authors length 2500
# dates length 2500
# description length 2500
# scraping page number 126
# statement length 2520
# authors length 2520
# dates length 2520
# description length 2520
# scraping page number 127
# statement length 2540
# authors length 2540
# dates length 2540
# description length 2540
# scraping page number 128
# statement length 2560
# authors length 2560
# dates length 2560
# description length 2560
# scraping page number 129
# statement length 2580
# authors length 2580
# dates length 2580
# description length 2580
# scraping page number 130
# statement length 2600
# authors length 2600
# dates length 2600
# description length 2600
# scraping page number 131
# statement length 2620
# authors length 2620
# dates length 2620
# description length 2620
# scraping page number 132
# statement length 2640
# authors length 2640
# dates length 2640
# description length 2640
# scraping page number 133
# statement length 2660
# authors length 2660
# dates length 2660
# description length 2660
# scraping page number 134
# statement length 2680
# authors length 2680
# dates length 2680
# description length 2680
# scraping page number 135
# statement length 2700
# authors length 2700
# dates length 2700
# description length 2700
# scraping page number 136
# statement length 2720
# authors length 2720
# dates length 2720
# description length 2720
# scraping page number 137
# statement length 2740
# authors length 2740
# dates length 2740
# description length 2740
# scraping page number 138
# statement length 2760
# authors length 2760
# dates length 2760
# description length 2760
# scraping page number 139
# statement length 2780
# authors length 2780
# dates length 2780
# description length 2780
# scraping page number 140
# statement length 2800
# authors length 2800
# dates length 2800
# description length 2800
# scraping page number 141
# statement length 2820
# authors length 2820
# dates length 2820
# description length 2820
# scraping page number 142
# statement length 2840
# authors length 2840
# dates length 2840
# description length 2840
# scraping page number 143
# statement length 2860
# authors length 2860
# dates length 2860
# description length 2860
# scraping page number 144
# statement length 2880
# authors length 2880
# dates length 2880
# description length 2880
# scraping page number 145
# statement length 2900
# authors length 2900
# dates length 2900
# description length 2900
# scraping page number 146
# statement length 2920
# authors length 2920
# dates length 2920
# description length 2920
# scraping page number 147
# statement length 2940
# authors length 2940
# dates length 2940
# description length 2940
# scraping page number 148
# statement length 2960
# authors length 2960
# dates length 2960
# description length 2960
# scraping page number 149
# statement length 2980
# authors length 2980
# dates length 2980
# description length 2980
# scraping page number 150
# statement length 3000
# authors length 3000
# dates length 3000
# description length 3000
# scraping page number 151
# statement length 3020
# authors length 3020
# dates length 3020
# description length 3020
# scraping page number 152
# statement length 3040
# authors length 3040
# dates length 3040
# description length 3040
# scraping page number 153
# statement length 3060
# authors length 3060
# dates length 3060
# description length 3060
# scraping page number 154
# statement length 3080
# authors length 3080
# dates length 3080
# description length 3080
# scraping page number 155
# statement length 3100
# authors length 3100
# dates length 3100
# description length 3100
# scraping page number 156
# statement length 3120
# authors length 3120
# dates length 3120
# description length 3120
# scraping page number 157
# statement length 3140
# authors length 3140
# dates length 3140
# description length 3140
# scraping page number 158
# statement length 3160
# authors length 3160
# dates length 3160
# description length 3160
# scraping page number 159
# statement length 3180
# authors length 3180
# dates length 3180
# description length 3180
# scraping page number 160
# statement length 3200
# authors length 3200
# dates length 3200
# description length 3200
# scraping page number 161
# statement length 3220
# authors length 3220
# dates length 3220
# description length 3220
# scraping page number 162
# statement length 3240
# authors length 3240
# dates length 3240
# description length 3240
# scraping page number 163
# statement length 3260
# authors length 3260
# dates length 3260
# description length 3260
# scraping page number 164
# statement length 3280
# authors length 3280
# dates length 3280
# description length 3280
# scraping page number 165
# statement length 3300
# authors length 3300
# dates length 3300
# description length 3300
# scraping page number 166
# statement length 3320
# authors length 3320
# dates length 3320
# description length 3320
# scraping page number 167
# statement length 3340
# authors length 3340
# dates length 3340
# description length 3340
# scraping page number 168
# statement length 3360
# authors length 3360
# dates length 3360
# description length 3360
# scraping page number 169
# statement length 3380
# authors length 3380
# dates length 3380
# description length 3380
# scraping page number 170
# statement length 3400
# authors length 3400
# dates length 3400
# description length 3400
# scraping page number 171
# statement length 3420
# authors length 3420
# dates length 3420
# description length 3420
# scraping page number 172
# statement length 3440
# authors length 3440
# dates length 3440
# description length 3440
# scraping page number 173
# statement length 3460
# authors length 3460
# dates length 3460
# description length 3460
# scraping page number 174
# statement length 3480
# authors length 3480
# dates length 3480
# description length 3480
# scraping page number 175
# statement length 3500
# authors length 3500
# dates length 3500
# description length 3500
# scraping page number 176
# statement length 3520
# authors length 3520
# dates length 3520
# description length 3520
# scraping page number 177
# statement length 3540
# authors length 3540
# dates length 3540
# description length 3540
# scraping page number 178
# statement length 3560
# authors length 3560
# dates length 3560
# description length 3560
# scraping page number 179
# statement length 3580
# authors length 3580
# dates length 3580
# description length 3580
# scraping page number 180
# statement length 3600
# authors length 3600
# dates length 3600
# description length 3600
# scraping page number 181
# statement length 3620
# authors length 3620
# dates length 3620
# description length 3620
# scraping page number 182
# statement length 3640
# authors length 3640
# dates length 3640
# description length 3640
# scraping page number 183
# statement length 3660
# authors length 3660
# dates length 3660
# description length 3660
# scraping page number 184
# statement length 3680
# authors length 3680
# dates length 3680
# description length 3680
# scraping page number 185
# statement length 3700
# authors length 3700
# dates length 3700
# description length 3700
# scraping page number 186
# statement length 3720
# authors length 3720
# dates length 3720
# description length 3720
# scraping page number 187
# statement length 3740
# authors length 3740
# dates length 3740
# description length 3740
# scraping page number 188
# statement length 3760
# authors length 3760
# dates length 3760
# description length 3760
# scraping page number 189
# statement length 3780
# authors length 3780
# dates length 3780
# description length 3780
# scraping page number 190
# statement length 3800
# authors length 3800
# dates length 3800
# description length 3800
# scraping page number 191
# statement length 3820
# authors length 3820
# dates length 3820
# description length 3820
# scraping page number 192
# statement length 3840
# authors length 3840
# dates length 3840
# description length 3840
# scraping page number 193
# statement length 3860
# authors length 3860
# dates length 3860
# description length 3860
# scraping page number 194
# statement length 3880
# authors length 3880
# dates length 3880
# description length 3880
# scraping page number 195
# statement length 3900
# authors length 3900
# dates length 3900
# description length 3900
# scraping page number 196
# statement length 3920
# authors length 3920
# dates length 3920
# description length 3920
# scraping page number 197
# statement length 3940
# authors length 3940
# dates length 3940
# description length 3940
# scraping page number 198
# statement length 3960
# authors length 3960
# dates length 3960
# description length 3960
# scraping page number 199
# statement length 3980
# authors length 3980
# dates length 3980
# description length 3980
# scraping page number 200
# statement length 4000
# authors length 4000
# dates length 4000
# description length 4000
# scraping page number 201
# statement length 4020
# authors length 4020
# dates length 4020
# description length 4020
# scraping page number 202
# statement length 4040
# authors length 4040
# dates length 4040
# description length 4040
# scraping page number 203
# statement length 4060
# authors length 4060
# dates length 4060
# description length 4060
# scraping page number 204
# statement length 4080
# authors length 4080
# dates length 4080
# description length 4080
# scraping page number 205
# statement length 4100
# authors length 4100
# dates length 4100
# description length 4100
# scraping page number 206
# statement length 4120
# authors length 4120
# dates length 4120
# description length 4120
# scraping page number 207
# statement length 4140
# authors length 4140
# dates length 4140
# description length 4140
# scraping page number 208
# statement length 4160
# authors length 4160
# dates length 4160
# description length 4160
# scraping page number 209
# statement length 4180
# authors length 4180
# dates length 4180
# description length 4180
# scraping page number 210
# statement length 4200
# authors length 4200
# dates length 4200
# description length 4200
# scraping page number 211
# statement length 4220
# authors length 4220
# dates length 4220
# description length 4220
# scraping page number 212
# statement length 4240
# authors length 4240
# dates length 4240
# description length 4240
# scraping page number 213
# statement length 4260
# authors length 4260
# dates length 4260
# description length 4260
# scraping page number 214
# statement length 4280
# authors length 4280
# dates length 4280
# description length 4280
# scraping page number 215
# statement length 4300
# authors length 4300
# dates length 4300
# description length 4300
# scraping page number 216
# statement length 4320
# authors length 4320
# dates length 4320
# description length 4320
# scraping page number 217
# statement length 4340
# authors length 4340
# dates length 4340
# description length 4340
# scraping page number 218
# statement length 4360
# authors length 4360
# dates length 4360
# description length 4360
# scraping page number 219
# statement length 4380
# authors length 4380
# dates length 4380
# description length 4380
# scraping page number 220
# statement length 4400
# authors length 4400
# dates length 4400
# description length 4400
# scraping page number 221
# statement length 4420
# authors length 4420
# dates length 4420
# description length 4420
# scraping page number 222
# statement length 4440
# authors length 4440
# dates length 4440
# description length 4440
# scraping page number 223
# statement length 4460
# authors length 4460
# dates length 4460
# description length 4460
# scraping page number 224
# statement length 4480
# authors length 4480
# dates length 4480
# description length 4480
# scraping page number 225
# statement length 4500
# authors length 4500
# dates length 4500
# description length 4500
# scraping page number 226
# statement length 4520
# authors length 4520
# dates length 4520
# description length 4520
# scraping page number 227
# statement length 4540
# authors length 4540
# dates length 4540
# description length 4540
# scraping page number 228
# statement length 4560
# authors length 4560
# dates length 4560
# description length 4560
# scraping page number 229
# statement length 4580
# authors length 4580
# dates length 4580
# description length 4580
# scraping page number 230
# statement length 4600
# authors length 4600
# dates length 4600
# description length 4600
# scraping page number 231
# statement length 4620
# authors length 4620
# dates length 4620
# description length 4620
# scraping page number 232
# statement length 4640
# authors length 4640
# dates length 4640
# description length 4640
# scraping page number 233
# statement length 4660
# authors length 4660
# dates length 4660
# description length 4660
# scraping page number 234
# statement length 4680
# authors length 4680
# dates length 4680
# description length 4680
# scraping page number 235
# statement length 4700
# authors length 4700
# dates length 4700
# description length 4700
# scraping page number 236
# statement length 4720
# authors length 4720
# dates length 4720
# description length 4720
# scraping page number 237
# statement length 4740
# authors length 4740
# dates length 4740
# description length 4740
# scraping page number 238
# statement length 4760
# authors length 4760
# dates length 4760
# description length 4760
# scraping page number 239
# statement length 4780
# authors length 4780
# dates length 4780
# description length 4780
# scraping page number 240
# statement length 4800
# authors length 4800
# dates length 4800
# description length 4800
# scraping page number 241
# statement length 4820
# authors length 4820
# dates length 4820
# description length 4820
# scraping page number 242
# statement length 4840
# authors length 4840
# dates length 4840
# description length 4840
# scraping page number 243
# statement length 4860
# authors length 4860
# dates length 4860
# description length 4860
# scraping page number 244
# statement length 4880
# authors length 4880
# dates length 4880
# description length 4880
# scraping page number 245
# statement length 4900
# authors length 4900
# dates length 4900
# description length 4900
# scraping page number 246
# statement length 4920
# authors length 4920
# dates length 4920
# description length 4920
# scraping page number 247
# statement length 4940
# authors length 4940
# dates length 4940
# description length 4940
# scraping page number 248
# statement length 4960
# authors length 4960
# dates length 4960
# description length 4960
# scraping page number 249
# statement length 4980
# authors length 4980
# dates length 4980
# description length 4980
# scraping page number 250
# statement length 5000
# authors length 5000
# dates length 5000
# description length 5000
# scraping page number 251
# statement length 5020
# authors length 5020
# dates length 5020
# description length 5020
# scraping page number 252
# statement length 5040
# authors length 5040
# dates length 5040
# description length 5040
# scraping page number 253
# statement length 5060
# authors length 5060
# dates length 5060
# description length 5060
# scraping page number 254
# statement length 5080
# authors length 5080
# dates length 5080
# description length 5080
# scraping page number 255
# statement length 5100
# authors length 5100
# dates length 5100
# description length 5100
# scraping page number 256
# statement length 5120
# authors length 5120
# dates length 5120
# description length 5120
# scraping page number 257
# statement length 5140
# authors length 5140
# dates length 5140
# description length 5140
# scraping page number 258
# statement length 5160
# authors length 5160
# dates length 5160
# description length 5160
# scraping page number 259
# statement length 5180
# authors length 5180
# dates length 5180
# description length 5180
# scraping page number 260
# statement length 5200
# authors length 5200
# dates length 5200
# description length 5200
# scraping page number 261
# statement length 5220
# authors length 5220
# dates length 5220
# description length 5220
# scraping page number 262
# statement length 5240
# authors length 5240
# dates length 5240
# description length 5240
# scraping page number 263
# statement length 5260
# authors length 5260
# dates length 5260
# description length 5260
# scraping page number 264
# statement length 5280
# authors length 5280
# dates length 5280
# description length 5280
# scraping page number 265
# statement length 5300
# authors length 5300
# dates length 5300
# description length 5300
# scraping page number 266
# statement length 5320
# authors length 5320
# dates length 5320
# description length 5320
# scraping page number 267
# statement length 5340
# authors length 5340
# dates length 5340
# description length 5340
# scraping page number 268
# statement length 5360
# authors length 5360
# dates length 5360
# description length 5360
# scraping page number 269
# statement length 5380
# authors length 5380
# dates length 5380
# description length 5380
# scraping page number 270
# statement length 5400
# authors length 5400
# dates length 5400
# description length 5400
# scraping page number 271
# statement length 5420
# authors length 5420
# dates length 5420
# description length 5420
# scraping page number 272
# statement length 5440
# authors length 5440
# dates length 5440
# description length 5440
# scraping page number 273
# statement length 5460
# authors length 5460
# dates length 5460
# description length 5460
# scraping page number 274
# statement length 5480
# authors length 5480
# dates length 5480
# description length 5480
# scraping page number 275
# statement length 5500
# authors length 5500
# dates length 5500
# description length 5500
# scraping page number 276
# statement length 5520
# authors length 5520
# dates length 5520
# description length 5520
# scraping page number 277
# statement length 5540
# authors length 5540
# dates length 5540
# description length 5540
# scraping page number 278
# statement length 5560
# authors length 5560
# dates length 5560
# description length 5560
# scraping page number 279
# statement length 5580
# authors length 5580
# dates length 5580
# description length 5580
# scraping page number 280
# statement length 5600
# authors length 5600
# dates length 5600
# description length 5600
# scraping page number 281
# statement length 5620
# authors length 5620
# dates length 5620
# description length 5620
# scraping page number 282
# statement length 5640
# authors length 5640
# dates length 5640
# description length 5640
# scraping page number 283
# statement length 5660
# authors length 5660
# dates length 5660
# description length 5660
# scraping page number 284
# statement length 5680
# authors length 5680
# dates length 5680
# description length 5680
# scraping page number 285
# statement length 5700
# authors length 5700
# dates length 5700
# description length 5700
# scraping page number 286
# statement length 5720
# authors length 5720
# dates length 5720
# description length 5720
# scraping page number 287
# statement length 5740
# authors length 5740
# dates length 5740
# description length 5740
# scraping page number 288
# statement length 5760
# authors length 5760
# dates length 5760
# description length 5760
# scraping page number 289
# statement length 5780
# authors length 5780
# dates length 5780
# description length 5780
# scraping page number 290
# statement length 5800
# authors length 5800
# dates length 5800
# description length 5800
# scraping page number 291
# statement length 5820
# authors length 5820
# dates length 5820
# description length 5820
# scraping page number 292
# statement length 5840
# authors length 5840
# dates length 5840
# description length 5840
# scraping page number 293
# statement length 5860
# authors length 5860
# dates length 5860
# description length 5860
# scraping page number 294
# statement length 5880
# authors length 5880
# dates length 5880
# description length 5880
# scraping page number 295
# statement length 5900
# authors length 5900
# dates length 5900
# description length 5900
# scraping page number 296
# statement length 5920
# authors length 5920
# dates length 5920
# description length 5920
# scraping page number 297
# statement length 5940
# authors length 5940
# dates length 5940
# description length 5940
# scraping page number 298
# statement length 5960
# authors length 5960
# dates length 5960
# description length 5960
# scraping page number 299
# statement length 5980
# authors length 5980
# dates length 5980
# description length 5980
# scraping page number 300
# statement length 6000
# authors length 6000
# dates length 6000
# description length 6000
# scraping page number 301
# statement length 6020
# authors length 6020
# dates length 6020
# description length 6020
# scraping page number 302
# statement length 6040
# authors length 6040
# dates length 6040
# description length 6040
# scraping page number 303
# statement length 6060
# authors length 6060
# dates length 6060
# description length 6060
# scraping page number 304
# statement length 6080
# authors length 6080
# dates length 6080
# description length 6080
# scraping page number 305
# statement length 6100
# authors length 6100
# dates length 6100
# description length 6100
# scraping page number 306
# statement length 6120
# authors length 6120
# dates length 6120
# description length 6120
# scraping page number 307
# statement length 6140
# authors length 6140
# dates length 6140
# description length 6140
# scraping page number 308
# statement length 6160
# authors length 6160
# dates length 6160
# description length 6160
# scraping page number 309
# statement length 6180
# authors length 6180
# dates length 6180
# description length 6180
# scraping page number 310
# statement length 6200
# authors length 6200
# dates length 6200
# description length 6200
# scraping page number 311
# statement length 6220
# authors length 6220
# dates length 6220
# description length 6220
# scraping page number 312
# statement length 6240
# authors length 6240
# dates length 6240
# description length 6240
# scraping page number 313
# statement length 6260
# authors length 6260
# dates length 6260
# description length 6260
# scraping page number 314
# statement length 6280
# authors length 6280
# dates length 6280
# description length 6280
# scraping page number 315
# statement length 6300
# authors length 6300
# dates length 6300
# description length 6300
# scraping page number 316
# statement length 6320
# authors length 6320
# dates length 6320
# description length 6320
# scraping page number 317
# statement length 6340
# authors length 6340
# dates length 6340
# description length 6340
# scraping page number 318
# statement length 6360
# authors length 6360
# dates length 6360
# description length 6360
# scraping page number 319
# statement length 6380
# authors length 6380
# dates length 6380
# description length 6380
# scraping page number 320
# statement length 6400
# authors length 6400
# dates length 6400
# description length 6400
# scraping page number 321
# statement length 6420
# authors length 6420
# dates length 6420
# description length 6420
# scraping page number 322
# statement length 6440
# authors length 6440
# dates length 6440
# description length 6440
# scraping page number 323
# statement length 6460
# authors length 6460
# dates length 6460
# description length 6460
# scraping page number 324
# statement length 6480
# authors length 6480
# dates length 6480
# description length 6480
# scraping page number 325
# statement length 6500
# authors length 6500
# dates length 6500
# description length 6500
# scraping page number 326
# statement length 6520
# authors length 6520
# dates length 6520
# description length 6520
# scraping page number 327
# statement length 6540
# authors length 6540
# dates length 6540
# description length 6540
# scraping page number 328
# statement length 6560
# authors length 6560
# dates length 6560
# description length 6560
# scraping page number 329
# statement length 6580
# authors length 6580
# dates length 6580
# description length 6580
# scraping page number 330
# statement length 6600
# authors length 6600
# dates length 6600
# description length 6600
# scraping page number 331
# statement length 6620
# authors length 6620
# dates length 6620
# description length 6620
# scraping page number 332
# statement length 6640
# authors length 6640
# dates length 6640
# description length 6640
# scraping page number 333
# statement length 6660
# authors length 6660
# dates length 6660
# description length 6660
# scraping page number 334
# statement length 6680
# authors length 6680
# dates length 6680
# description length 6680
# scraping page number 335
# statement length 6700
# authors length 6700
# dates length 6700
# description length 6700
# scraping page number 336
# statement length 6720
# authors length 6720
# dates length 6720
# description length 6720
# scraping page number 337
# statement length 6740
# authors length 6740
# dates length 6740
# description length 6740
# scraping page number 338
# statement length 6760
# authors length 6760
# dates length 6760
# description length 6760
# scraping page number 339
# statement length 6780
# authors length 6780
# dates length 6780
# description length 6780
# scraping page number 340
# statement length 6800
# authors length 6800
# dates length 6800
# description length 6800
# scraping page number 341
# statement length 6820
# authors length 6820
# dates length 6820
# description length 6820
# scraping page number 342
# statement length 6840
# authors length 6840
# dates length 6840
# description length 6840
# scraping page number 343
# statement length 6860
# authors length 6860
# dates length 6860
# description length 6860
# scraping page number 344
# statement length 6880
# authors length 6880
# dates length 6880
# description length 6880
# scraping page number 345
# statement length 6900
# authors length 6900
# dates length 6900
# description length 6900
# scraping page number 346
# statement length 6920
# authors length 6920
# dates length 6920
# description length 6920
# scraping page number 347
# statement length 6940
# authors length 6940
# dates length 6940
# description length 6940
# scraping page number 348
# statement length 6960
# authors length 6960
# dates length 6960
# description length 6960
# scraping page number 349
# statement length 6980
# authors length 6980
# dates length 6980
# description length 6980
# scraping page number 350
# statement length 7000
# authors length 7000
# dates length 7000
# description length 7000
# scraping page number 351
# statement length 7020
# authors length 7020
# dates length 7020
# description length 7020
# scraping page number 352
# statement length 7040
# authors length 7040
# dates length 7040
# description length 7040
# scraping page number 353
# statement length 7060
# authors length 7060
# dates length 7060
# description length 7060
# scraping page number 354
# statement length 7080
# authors length 7080
# dates length 7080
# description length 7080
# scraping page number 355
# statement length 7100
# authors length 7100
# dates length 7100
# description length 7100
# scraping page number 356
# statement length 7120
# authors length 7120
# dates length 7120
# description length 7120
# scraping page number 357
# statement length 7140
# authors length 7140
# dates length 7140
# description length 7140
# scraping page number 358
# statement length 7160
# authors length 7160
# dates length 7160
# description length 7160
# scraping page number 359
# statement length 7180
# authors length 7180
# dates length 7180
# description length 7180
# scraping page number 360
# statement length 7200
# authors length 7200
# dates length 7200
# description length 7200
# scraping page number 361
# statement length 7220
# authors length 7220
# dates length 7220
# description length 7220
# scraping page number 362
# statement length 7240
# authors length 7240
# dates length 7240
# description length 7240
# scraping page number 363
# statement length 7260
# authors length 7260
# dates length 7260
# description length 7260
# scraping page number 364
# statement length 7280
# authors length 7280
# dates length 7280
# description length 7280
# scraping page number 365
# statement length 7300
# authors length 7300
# dates length 7300
# description length 7300
# scraping page number 366
# statement length 7320
# authors length 7320
# dates length 7320
# description length 7320
# scraping page number 367
# statement length 7340
# authors length 7340
# dates length 7340
# description length 7340
# scraping page number 368
# statement length 7360
# authors length 7360
# dates length 7360
# description length 7360
# scraping page number 369
# statement length 7380
# authors length 7380
# dates length 7380
# description length 7380
# scraping page number 370
# statement length 7400
# authors length 7400
# dates length 7400
# description length 7400
# scraping page number 371
# statement length 7420
# authors length 7420
# dates length 7420
# description length 7420
# scraping page number 372
# statement length 7440
# authors length 7440
# dates length 7440
# description length 7440
# scraping page number 373
# statement length 7460
# authors length 7460
# dates length 7460
# description length 7460
# scraping page number 374
# statement length 7480
# authors length 7480
# dates length 7480
# description length 7480
# scraping page number 375
# statement length 7500
# authors length 7500
# dates length 7500
# description length 7500
# scraping page number 376
# statement length 7520
# authors length 7520
# dates length 7520
# description length 7520
# scraping page number 377
# statement length 7540
# authors length 7540
# dates length 7540
# description length 7540
# scraping page number 378
# statement length 7560
# authors length 7560
# dates length 7560
# description length 7560
# scraping page number 379
# statement length 7580
# authors length 7580
# dates length 7580
# description length 7580
# scraping page number 380
# statement length 7600
# authors length 7600
# dates length 7600
# description length 7600
# scraping page number 381
# statement length 7620
# authors length 7620
# dates length 7620
# description length 7620
# scraping page number 382
# statement length 7640
# authors length 7640
# dates length 7640
# description length 7640
# scraping page number 383
# statement length 7660
# authors length 7660
# dates length 7660
# description length 7660
# scraping page number 384
# statement length 7680
# authors length 7680
# dates length 7680
# description length 7680
# scraping page number 385
# statement length 7700
# authors length 7700
# dates length 7700
# description length 7700
# scraping page number 386
# statement length 7720
# authors length 7720
# dates length 7720
# description length 7720
# scraping page number 387
# statement length 7740
# authors length 7740
# dates length 7740
# description length 7740
# scraping page number 388
# statement length 7760
# authors length 7760
# dates length 7760
# description length 7760
# scraping page number 389
# statement length 7780
# authors length 7780
# dates length 7780
# description length 7780
# scraping page number 390
# statement length 7800
# authors length 7800
# dates length 7800
# description length 7800
# scraping page number 391
# statement length 7820
# authors length 7820
# dates length 7820
# description length 7820
# scraping page number 392
# statement length 7840
# authors length 7840
# dates length 7840
# description length 7840
# scraping page number 393
# statement length 7860
# authors length 7860
# dates length 7860
# description length 7860
# scraping page number 394
# statement length 7880
# authors length 7880
# dates length 7880
# description length 7880
# scraping page number 395
# statement length 7900
# authors length 7900
# dates length 7900
# description length 7900
# scraping page number 396
# statement length 7920
# authors length 7920
# dates length 7920
# description length 7920
# scraping page number 397
# statement length 7940
# authors length 7940
# dates length 7940
# description length 7940
# scraping page number 398
# statement length 7960
# authors length 7960
# dates length 7960
# description length 7960
# scraping page number 399
# statement length 7980
# authors length 7980
# dates length 7980
# description length 7980
# scraping page number 400
# statement length 8000
# authors length 8000
# dates length 8000
# description length 8000
# scraping page number 401
# statement length 8020
# authors length 8020
# dates length 8020
# description length 8020
# scraping page number 402
# statement length 8040
# authors length 8040
# dates length 8040
# description length 8040
# scraping page number 403
# statement length 8060
# authors length 8060
# dates length 8060
# description length 8060
# scraping page number 404
# statement length 8080
# authors length 8080
# dates length 8080
# description length 8080
# scraping page number 405
# statement length 8100
# authors length 8100
# dates length 8100
# description length 8100
# scraping page number 406
# statement length 8120
# authors length 8120
# dates length 8120
# description length 8120
# scraping page number 407
# statement length 8140
# authors length 8140
# dates length 8140
# description length 8140
# scraping page number 408
# statement length 8160
# authors length 8160
# dates length 8160
# description length 8160
# scraping page number 409
# statement length 8180
# authors length 8180
# dates length 8180
# description length 8180
# scraping page number 410
# statement length 8200
# authors length 8200
# dates length 8200
# description length 8200
# scraping page number 411
# statement length 8220
# authors length 8220
# dates length 8220
# description length 8220
# scraping page number 412
# statement length 8240
# authors length 8240
# dates length 8240
# description length 8240
# scraping page number 413
# statement length 8260
# authors length 8260
# dates length 8260
# description length 8260
# scraping page number 414
# statement length 8280
# authors length 8280
# dates length 8280
# description length 8280
# scraping page number 415
# statement length 8300
# authors length 8300
# dates length 8300
# description length 8300
# scraping page number 416
# statement length 8320
# authors length 8320
# dates length 8320
# description length 8320
# scraping page number 417
# statement length 8340
# authors length 8340
# dates length 8340
# description length 8340
# scraping page number 418
# statement length 8360
# authors length 8360
# dates length 8360
# description length 8360
# scraping page number 419
# statement length 8380
# authors length 8380
# dates length 8380
# description length 8380
# scraping page number 420
# statement length 8400
# authors length 8400
# dates length 8400
# description length 8400
# scraping page number 421
# statement length 8420
# authors length 8420
# dates length 8420
# description length 8420
# scraping page number 422
# statement length 8440
# authors length 8440
# dates length 8440
# description length 8440
# scraping page number 423
# statement length 8460
# authors length 8460
# dates length 8460
# description length 8460
# scraping page number 424
# statement length 8480
# authors length 8480
# dates length 8480
# description length 8480
# scraping page number 425
# statement length 8500
# authors length 8500
# dates length 8500
# description length 8500
# scraping page number 426
# statement length 8520
# authors length 8520
# dates length 8520
# description length 8520
# scraping page number 427
# statement length 8540
# authors length 8540
# dates length 8540
# description length 8540
# scraping page number 428
# statement length 8560
# authors length 8560
# dates length 8560
# description length 8560
# scraping page number 429
# statement length 8580
# authors length 8580
# dates length 8580
# description length 8580
# scraping page number 430
# statement length 8600
# authors length 8600
# dates length 8600
# description length 8600
# scraping page number 431
# statement length 8620
# authors length 8620
# dates length 8620
# description length 8620
# scraping page number 432
# statement length 8640
# authors length 8640
# dates length 8640
# description length 8640
# scraping page number 433
# statement length 8660
# authors length 8660
# dates length 8660
# description length 8660
# scraping page number 434
# statement length 8680
# authors length 8680
# dates length 8680
# description length 8680
# scraping page number 435
# statement length 8700
# authors length 8700
# dates length 8700
# description length 8700
# scraping page number 436
# statement length 8720
# authors length 8720
# dates length 8720
# description length 8720
# scraping page number 437
# statement length 8740
# authors length 8740
# dates length 8740
# description length 8740
# scraping page number 438
# statement length 8760
# authors length 8760
# dates length 8760
# description length 8760
# scraping page number 439
# statement length 8780
# authors length 8780
# dates length 8780
# description length 8780
# scraping page number 440
# statement length 8800
# authors length 8800
# dates length 8800
# description length 8800
# scraping page number 441
# statement length 8820
# authors length 8820
# dates length 8820
# description length 8820
# scraping page number 442
# statement length 8840
# authors length 8840
# dates length 8840
# description length 8840
# scraping page number 443
# statement length 8860
# authors length 8860
# dates length 8860
# description length 8860
# scraping page number 444
# ...
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 842
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 843
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 844
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 845
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 846
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 847
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 848
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 849
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 850
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 851
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 852
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 853
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 854
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 855
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 856
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 857
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 858
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 859
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 860
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 861
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 862
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 863
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 864
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 865
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 866
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 867
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 868
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 869
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 870
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 871
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 872
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 873
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 874
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 875
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 876
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 877
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 878
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 879
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 880
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 881
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 882
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 883
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 884
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 885
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 886
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 887
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 888
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 889
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 890
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 891
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 892
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 893
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 894
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 895
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 896
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 897
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 898
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 899
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 900
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 901
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 902
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 903
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 904
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 905
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 906
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 907
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 908
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 909
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 910
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 911
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 912
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 913
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 914
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 915
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 916
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 917
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 918
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 919
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 920
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 921
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 922
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 923
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 924
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 925
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 926
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 927
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 928
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 929
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 930
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 931
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 932
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 933
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 934
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 935
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 936
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 937
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 938
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 939
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 940
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 941
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 942
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 943
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 944
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 945
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 946
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 947
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 948
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 949
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 950
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 951
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 952
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 953
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 954
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 955
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 956
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 957
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 958
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 959
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 960
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 961
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 962
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 963
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 964
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 965
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 966
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 967
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 968
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 969
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 970
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 971
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 972
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 973
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 974
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 975
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 976
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 977
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 978
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 979
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 980
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 981
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000
# scraping page number 982
# statement length 13000
# authors length 13000
# dates length 13000
# description length 13000

# %%
#Create a new dataFrame 

data = pd.DataFrame(columns = ['author',  'statement', 'date', 'description']) 
data['author'] = authors
data['statement'] = statements
data['date'] = dates
data['description'] = description

# %%
#show dataset
data.head()
# Out:
#                 author                                          statement  \
# 0        [Nur Ibrahim]  Did Lady Gaga’s College Classmates Create Face...
# 1        [Nur Ibrahim]  Yes, This Pic Shows Jet that Landed Safely Aft...
# 2  [Barbara Mikkelson]  Did a Bargain Hunter Find Original Print of De...
# 3        [David Emery]  No, Biden and Alex Soros Weren't Photographed ...
# 4    [Damakant Jayshi]  Did Jerry Springer Once Say He Didn't Watch Hi...
#
#            date                                        description
# 0  Apr 30, 2023  It was allegedly titled "Stefani Germanotta, y...
# 1  Apr 29, 2023  A flight attendant was killed after being "suc...
# 2  Jun 29, 2000  A lucky bargain hunter got more than he bargai...
# 3  Apr 28, 2023  No sooner had George Soros' son Alexander post...
# 4  Apr 28, 2023  The 2014 video clip appeared to show the epony...

# %%
#show dataset
data
# Out:
#                     author                                          statement  \
# 0            [Nur Ibrahim]  Did Lady Gaga’s College Classmates Create Face...
# 1            [Nur Ibrahim]  Yes, This Pic Shows Jet that Landed Safely Aft...
# 2      [Barbara Mikkelson]  Did a Bargain Hunter Find Original Print of De...
# 3            [David Emery]  No, Biden and Alex Soros Weren't Photographed ...
# 4        [Damakant Jayshi]  Did Jerry Springer Once Say He Didn't Watch Hi...
# ...                    ...                                                ...
# 12995    [David Mikkelson]                              Passing the Starbucks
# 12996       [Kim LaCapria]                                 Chicken Fried Fake
# 12997           [Dan Evon]  Was 'Little Timmy Salutes the Flag' Banned by ...
# 12998       [Kim LaCapria]      Did Ben Carson's Family Benefit from Welfare?
# 12999           [Dan Evon]                                         Powerchord
#
#                date                                        description
# 0      Apr 30, 2023  It was allegedly titled "Stefani Germanotta, y...
# 1      Apr 29, 2023  A flight attendant was killed after being "suc...
# 2      Jun 29, 2000  A lucky bargain hunter got more than he bargai...
# 3      Apr 28, 2023  No sooner had George Soros' son Alexander post...
# 4      Apr 28, 2023  The 2014 video clip appeared to show the epony...
# ...             ...                                                ...
# 12995  Oct 31, 2015  Starbucks isn't giving away free lifetime pass...
# 12996  Oct 30, 2015  No, the FDA hasn't confiscated mutated chicken...
# 12997  Oct 30, 2015  Facebook  supposedly removed a photograph of "...
# 12998  Oct 29, 2015  Memes assert Ben Carson benefited from welfare...
# 12999  Oct 29, 2015  The band Godsmack is not changing their name t...
#
# [13000 rows x 4 columns]

# %%
#Store the results of scraping first 9 pages to a CSV file
data.to_csv('Snopes Data 1-982.csv')
