# %%
#install packages
# !pip3 install requests
# !pip3 install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)

# %%
#import packages
import urllib.request
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Reinitializ every time yyou run the program create lists to store data scraped from web
authors = []
dates = []
statements = []
sources = []
targets = []

# %%
def scrape_data(page_number):
    page_num = str(page_number)
    print('scraping page number', page_num)
    URL= 'https://www.politifact.com/factchecks/list/?page='+page_num
    webpage = requests.get(URL)
    soup = BeautifulSoup(webpage.text,"html.parser")
    statement_quote = soup.find_all('div', attrs={'class':'m-statement__quote'}) #Get the tag and it's class
    statement_footer =  soup.find_all('footer',attrs={'class':'m-statement__footer'})  #Get the tag and it's class
    statement_meta = soup.find_all('div', attrs={'class':'m-statement__meta'})#Get the tag and it's class
    target = soup.find_all('div', attrs={'class':'m-statement__meter'}) #Get the tag and it's class
   
    #loop through the footer class m-statement__footer to get the date and author
    for i in statement_footer:
        text = i.text.strip()
        name_and_date = text.split()
        full_name = name_and_date[1]+' '+name_and_date[2]
        date = name_and_date[4]+' '+name_and_date[5]+' '+name_and_date[6]
        dates.append(date)
        authors.append(full_name)

    #Loop through the div m-statement__quote to get the link
    for i in statement_quote:
        stmt_quote_links = i.find_all('a')
        statements.append(stmt_quote_links[0].text.strip())

    #Loop through the div m-statement__meta to get the source
    for i in statement_meta:
        link3 = i.find_all('a') #Source
        source_text = link3[0].text.strip()
        sources.append(source_text)
        
    #Loop through the target or the div m-statement__meter to get the facts about the statement (True or False)
    for i in target:
        fact = i.find('div', attrs={'class':'c-image'}).find('img').get('alt')
        targets.append(fact)

# %%
#Loop over 100 to 200 pages
for i in range(100, 151):
  scrape_data(i)
# Out:
# page nuumber 100
# page nuumber 101
# page nuumber 102
# page nuumber 103
# page nuumber 104
# page nuumber 105
# page nuumber 106
# page nuumber 107
# page nuumber 108
# page nuumber 109
# page nuumber 110
# page nuumber 111
# page nuumber 112
# page nuumber 113
# page nuumber 114
# page nuumber 115
# page nuumber 116
# page nuumber 117
# page nuumber 118
# page nuumber 119
# page nuumber 120
# page nuumber 121
# page nuumber 122
# page nuumber 123
# page nuumber 124
# page nuumber 125
# page nuumber 126
# page nuumber 127
# page nuumber 128
# page nuumber 129
# page nuumber 130
# page nuumber 131
# page nuumber 132
# page nuumber 133
# page nuumber 134
# page nuumber 135
# page nuumber 136
# page nuumber 137
# page nuumber 138
# page nuumber 139
# page nuumber 140
# page nuumber 141
# page nuumber 142
# page nuumber 143
# page nuumber 144
# page nuumber 145
# page nuumber 146
# page nuumber 147
# page nuumber 148
# page nuumber 149
# page nuumber 150

# %%
#Create a new dataFrame 

data = pd.DataFrame(columns = ['author',  'statement', 'source', 'date', 'target']) 
data['author'] = authors
data['statement'] = statements
data['source'] = sources
data['date'] = dates
data['target'] = targets

# %%
#show dataset
data.head()
# Out:
#               author                                          statement  \
# 0     Brandon Mulder  “In Texas, the power companies have automatica...
# 1      Bill McCarthy  “We know most of our forefathers, all of our m...
# 2         Emily Tian  Charcoal activated tablets “will counteract mo...
# 3      Madeline Heim     “Wisconsin is 49th in public health spending.”
# 4  Gabrielle Settles  Says George Floyd died "because he had a syste...
#
#              source          date       target
# 0    Tucker Carlson  July 9, 2021        false
# 1  Kayleigh McEnany  July 9, 2021  barely-true
# 2    Facebook posts  July 9, 2021        false
# 3     Jon Erpenbach  July 9, 2021    half-true
# 4    Facebook posts  July 8, 2021        false

# %%
#we are only onterested in pants-fire and false news articles to create our fake news dataset
fake = ['pants-fire','false']
fake_df = data[data['target'].isin(fake)]
fake_df.shape
# Out:
# (1000, 5)

# %%
#show dataset
fake_df
# Out:
#                   author                                          statement  \
# 0         Brandon Mulder  “In Texas, the power companies have automatica...
# 2             Emily Tian  Charcoal activated tablets “will counteract mo...
# 4      Gabrielle Settles  Says George Floyd died "because he had a syste...
# 6         Louis Jacobson  "The person that shot Ashli Babbitt — boom — r...
# 7         Ciara O'Rourke  “Facebook said that if you support the NRA you...
# ...                  ...                                                ...
# 1520      Ciara O'Rourke  Says Facebook “is banning Trump from advertisi...
# 1522  Samantha Putterman  A clip of Joe Biden shows him reading a respon...
# 1524      Ciara O'Rourke                     Photos show children in cages.
# 1526      Ciara O'Rourke  “Joe Biden completely botches the Pledge of Al...
# 1529       Jon Greenberg  “Putting a national lockdown, stay-at-home ord...
#
#                source                date      target
# 0      Tucker Carlson        July 9, 2021       false
# 2      Facebook posts        July 9, 2021       false
# 4      Facebook posts        July 8, 2021       false
# 6        Donald Trump        July 8, 2021       false
# 7      Facebook posts        July 8, 2021       false
# ...               ...                 ...         ...
# 1520   Facebook posts  September 23, 2020       false
# 1522  Instagram posts  September 23, 2020  pants-fire
# 1524      Viral image  September 23, 2020       false
# 1526           Tweets  September 22, 2020       false
# 1529     William Barr  September 22, 2020       false
#
# [1000 rows x 5 columns]

# %%
#Store the results of scraping first 9 pages to a CSV file
fake_df.to_csv('fake_news100-150.csv')
